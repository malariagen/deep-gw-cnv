# %%
# !date
# Out:
# Fri Mar 13 10:02:31 GMT 2026

# %%
# %%bash
#
# bsub \
#     -J "rc2zarr" \
#     -o "log.o" \
#     -e "log.e" \
#     -q basement \
#     -G team342 \
#     -R "select[mem>48000] rusage[mem=48000]" \
#     -M 48000 \
#     -n 8 \
#     "python3 readcounts_to_zarr.py"
# Out:
# Job <701873> is submitted to queue <basement>.
